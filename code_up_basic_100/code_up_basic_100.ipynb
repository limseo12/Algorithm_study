# %% [markdown]
# <a href="https://colab.research.google.com/github/limseo12/Algorithm_study/blob/main/code_up_basic_100/code_up_basic_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# #1
# print('hello')    #변수에 저장된 값이 없을 때에는 '' 따옴표가 필요하다

# #2
# print('Hello World')

# #3
# print("Hello\nworld")

# #4
# print("'Hello'")

# #5
# print('"Hello World"')

# #6
# print()

# #7
# print("\"C:\\Download\\'hello'.py\"")
# #8
# print("print(\"Hello\\nworld\")")

#9
# c=input()
# print(c)

#10
# n=input()
# n=int(n)
# print(n)

#11
# f = input()
# f = float(f)
# print(f)

#12
# a = input()
# b = input()
# a = int(a)
# b = int(b)
# print(a)
# print(b)

#13
# a = input()
# b = input()
# print(a)
# print(b)

#14
# a = input()
# a = float(a)
# print(a)
# print(a)
# print(a)

#15
# a, b = input().split()
# a=int(a)
# b=int(b)
# print(a)
# print(b)

#16
# a, b = input().split()
# print(b,a)

#17
# s = input()
# print(s, s, s)

#18

# a, b = input().split(':')
# print(a,b ,sep=':')

#19.
# a, b, c = input().split('.')
# print(c, b ,a ,sep='-')

#20
# a, b = input().split('-')
# print(a, b, sep='')

#21
# s = input()
# print(s[0])
# print(s[1])
# print(s[2])
# print(s[3])
# print(s[4])

#22
# s = input()
# print(s[0:2],s[2:4],s[4:])

#23
# o,m,s = input().split(':')
# print(m)

#24
# w1, w2 = input().split()
# print(w1+w2)

#25 (6025) 기초 값 변환
# a, b = input().split()
# print(int(a)+int(b))

#26
# a, b = input().split()
# print(float(a) + float(b))

#27 (6027) 출력변환
# a = input()
# n= int(a)
# print('%x'%n)

#28
# a = input()
# n = int(a)
# print('%x'%n)

#29
# a = input()
# n = int(a, 16)
# print('%o'%n)

#30 (6030)
