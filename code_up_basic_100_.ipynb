# %% [markdown]
# <a href="https://colab.research.google.com/github/limseo12/Algorithm_study/blob/main/code_up_basic_100_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# #1
# print('hello')    #변수에 저장된 값이 없을 때에는 '' 따옴표가 필요하다

# #2
# print('Hello World')

# #3
# print("Hello\nworld")

# #4
# print("'Hello'")

# #5
# print('"Hello World"')

# #6
# print()

# #7
# print("\"C:\\Download\\'hello'.py\"")
# #8
# print("print(\"Hello\\nworld\")")

#9
# c=input()
# print(c)

#10
# n=input()
# n=int(n)
# print(n)

#11
# f = input()
# f = float(f)
# print(f)

#12
# a = input()
# b = input()
# a = int(a)
# b = int(b)
# print(a)
# print(b)

#13
# a = input()
# b = input()
# print(a)
# print(b)

#14
# a = input()
# a = float(a)
# print(a)
# print(a)
# print(a)

#15
# a, b = input().split()
# a=int(a)
# b=int(b)
# print(a)
# print(b)

#16
# a, b = input().split()
# print(b,a)

#17
# s = input()
# print(s, s, s)

#18

# a, b = input().split(':')
# print(a,b ,sep=':')

#19.
# a, b, c = input().split('.')
# print(c, b ,a ,sep='-')

#20
# a, b = input().split('-')
# print(a, b, sep='')

#21
# s = input()
# print(s[0])
# print(s[1])
# print(s[2])
# print(s[3])
# print(s[4])

#22
# s = input()
# print(s[0:2],s[2:4],s[4:])

#23
# o,m,s = input().split(':')
# print(m)

#24
# w1, w2 = input().split()
# print(w1+w2)

#25 (6025) 기초 값 변환
# a, b = input().split()
# print(int(a)+int(b))

#26
# a, b = input().split()
# print(float(a) + float(b))

#27 (6027) 출력변환
# a = input()
# n= int(a)
# print('%x'%n)

#28
# a = input()
# n = int(a)
# print('%x'%n)

#29
# a = input()
# n = int(a, 16)
# print('%o'%n)

#30 (6030) ord유니코드
# n = ord(input())
# print(n)

#31 chr 정수 값을 유니코드 문자로 바꾸어 출력한다
# c = int(input())
# print(chr(c))

#32 6032
# c = int(input())
# print(-c)

#33 아스키 값을 이용하기 때문에 ord
# n = ord(input())
# print(chr(n+1))

#34 6034
# a, b = map(int, input().split())
# print(a-b)

#35 6035
# f1 , f2 = map(float, input().split())
# print(f1*f2)

# 36 6036
# w, n = input().split()
# print(w*int(n))

# 37 
# n = int(input())
# s = input()
# print(n*s)

#38
# a , b = map(int, input().split())
# print(a**b)

#39 6039
# a, b = map(float, input().split())
# print(a**b)

#40 6040
# a, b = map(int, input().split())
# print(a//b)

#41 6041
# a, b = map(int, input().split())
# print(a%b)

#42 6042
# a = float(input())
# print(format(a, ".2f"))

#43 6043
# f1, f2 = map(float, input().split())
# print(format(f1/f2, ".3f"))

#44 6044
# a , b = map(int, input().split())

# print(a+b)
# print(a-b)
# print(a*b)
# print(a//b)
# print(a%b)
# print(format(a/b, ".2f"))

#45 6045
# a, b ,c = map(int, input().split())
# sum = a + b + c
# avg = sum / 3
# print(sum, format(avg, "0.2f"))

#46 6046
# n = int(input())
# print(n<<1)

##47
# a , b = map(int, input().split())
# print(a<<b)

#48 6048
#1
# a , b = map(int, input().split())
# if (a < b):
#   print(True)
# else :
#   print(False)

#2
# a, b = map(int, input().split())
# print(a>b)

#49 6049
# a , b = map(int, input().split())
# print(a==b)

#50 6050
# a , b = map(int, input().split())
# print(a<=b)

#51 6051
# a, b = map(int, input().split())
# print(a!=b)

#52 6052
# n = int(input())
# print(bool(n))

#53 6053
# a = bool(int(input()))
# print(not a)

#54 6054
# a, b = map(int, input().split())
# print(bool(a) and bool(b))

#55 6055
# a, b = map(int, input().split())
# print(bool(a) or bool(b))

#56 6056
# a, b = map(int, input().split())
# print(bool(a) != bool(b))

#57 6057 
# a, b = map(int, input().split())
# print(bool(a) == bool(b))

#58 6058
# a, b = map(int, input().split())
# print(bool(a) == bool(b) == False)

#59 6059
# a = int(input())
# print(~a)

#60 6060
# a, b = map(int, input().split())
# print(a&b)

#61 6061
# a, b = map(int, input().split())
# print(a|b)

#62 6062
# a, b = map(int, input().split())
# print(a^b)

#63 6063
#1
# a , b = map(int, input().split())
# if (a>b):
#   print(a)
# else:
#   print(b)
#2
# a, b = map(int, input().split())
# print(a if a>b else b)

#64 6064
# a , b , c = map(int, input().split())
# print((a if a>b else b)if ((a if a>b else b)>c) else c )

#65 6065
# a , b , c = map(int, input().split())
# if a%2 == 0:
#   print(a)
# if b%2 == 0:
#   print(b)
# if c%2 == 0:
#   print(c)

#66 6066
# a, b, c = map(int, input().split())
# if a%2 == 0:
#   print("even")
# else:
#   print("odd")

# if b%2 == 0:
#   print("even")
# else:
#   print("odd")

# if c%2 == 0:
#   print("even")
# else:
#   print("odd")

#67 6067
# a = int(input())

# if (a<0):
#   if a%2 == 0:
#     print("A")
#   else:
#     print("B")
# else:
#   if a%2 == 0:
#     print("C")
#   else:
#     print("D")

#68 6068
#1
# a = int(input())

# if (a>90):
#   print('A')
# else:
#   if (a>80):
#     print('B')
#   else:
#     if(a>70):
#       print('C')
#     else:
#       if(a>60):
#         print('D')
#       else:
#         print('F')

#2
# a = int(input())

# if (a >= 90):
#   print('A')
# elif (90 > a >= 80):
#   print('B')
# elif (80 > a >=70):
#   print('C')
# else :
#   print('D')

#69 6069
# a = input()

# if (a == 'A'):
#   print('best!!')
# elif (a == 'B'):
#   print('good!!')
# elif (a == 'C'):
#   print('Run!')
# elif (a == 'D'):
#   print('slowly~')
# else :
#   print('what?')

#70 6070
# a = int(input())

# if (a//3 == 1):
#   print('spring')
# elif (a//3 ==2):
#   print('summer')
# elif (a//3 ==3):
#   print('Fall')
# else:
#   print('winter')

#71 6071
# while True:
#   a = int(input())
#   if a == 0:
#     break
#   else:
#     print(a)

#72 6072
# a = int(input())
# while a != 0:
#   print(a)
#   a -= 1
#   if a ==0:
#     break

#73 6073
#2 simple
# n=int(input())
# while n!=0:
#     n-=1
#     print(n)

#6074
# c = ord(input())
# t = ord('a')
# while t<=c:
#   print(chr(t), end='')
#   t +=1

#6075 
# n = int(input())
# for i in range(n+1):
#     print(i)

#6076
# n = int(input())
# for i in range(n+1):
#   print(i)

#6077
#1 for문
# n = int(input())
# s = 0
# for i in range(1, n+1):
#   if i%2==0:
#     s += i
# print(s)

#2 while문
# i, result = 2, 0
# a = int(input())
# while (i <= a):
#   result += i
#   i += 2
# print (result)

#78 6078
# while (a !='q'):
#   a = input()
#   print(a)

#79 6079
# n = int(input())
# s = 0
# t = 0
# while s<n:
#   t = t+1
#   s = s+t
# print(t)

#80 6080
# n, m = map(int, input().split())

# for i in range(1, n+1):
#   for j in range(1, m+1):
#     print(i, j)

#81 6081
# n = int(input(), 16)

# for i in range(1, 16) :
#   print('%X'%n, '*%X'%i, '=%X'%(n*i), sep='')


#82 6082
# n = int(input())

# for i in range(1, n+1):
#   if i%10==3 or i%10==6 or i%10==9:
#     print("X", end=' ')
#   else:
#     print(i, end=' ')

#83 6083
# r, g, b = map(int, input().split())

# for i in range(0, r):
#   for j in range(0, g):
#     for k in range(0, b):
#       print(i, j, k)
# print(r*g*b)

#84 6084
# h,b,c,s = map(int, input().split())
# m = (h* b * c * s)/8/1024/1024
# print('%.1f MB' %m)

#85 6085

# a, b, c = map(int, input().split())

# totalbit=a*b*c
# totalbyte=totalbit/8
# totalkb=totalbyte/1024
# totalmb=totalkb/1024

# print("%0.2f MB" % totalmb)

#86 6086
# n= int(input())
# i=0
# sum=0
# while True:
#   sum+=i
#   i+=1
#   if(sum>=n):
#      break
# print(sum)


#87 6087
